# %%
import requests
import requests as r
import pandas as pd

url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'technology',
    'apikey': '4dbedf035ac440d8a6f8f666b20b9220'
}
response = r.get(url, params=params)

#save response to a json file
data = response.json()
print(data)
# Out:
# {'status': 'ok', 'totalResults': 70, 'articles': [{'source': {'id': None, 'name': 'MacRumors'}, 'author': 'Juli Clover', 'title': 'Apple Seeds Second Release Candidate Versions of iOS 18.2 and More With Genmoji, Image Playground and ChatGPT Integration - MacRumors', 'description': 'Apple today seeded the second release candidate versions of upcoming iOS 18.2, iPadOS 18.2, and macOS 15.2 updates to developers and public beta...', 'url': 'https://www.macrumors.com/2024/12/09/apple-seeds-ios-18-2-second-rc/', 'urlToImage': 'https://images.macrumors.com/t/u419F9T-2zXWL5Hkvaw4AqK7ZBg=/2500x/article-new/2024/10/Generic-iOS-18.2-Feature-Real-Mock.jpg', 'publishedAt': '2024-12-09T18:06:36Z', 'content': 'Apple today seeded the second release candidate versions of upcoming iOS 18.2, iPadOS 18.2, and macOS 15.2 updates to developers and public beta testers for testing purposes, a week after releasing t… [+5323 chars]'}, {'source': {'id': 'techcrunch', 'name': 'TechCrunch'}, 'author': 'Kyle Wigg
# ...

# %%
import requests
import requests as r
import pandas as pd
url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'health',
    'category':  'technology',
    'category':  'sports',
    'apikey': "4dbedf035ac440d8a6f8f666b20b9220"
}
response = r.get(url, params=params)

#save response to a json file
data = response.json()
data
# Out:
# {'status': 'ok',
#  'totalResults': 26,
#  'articles': [{'source': {'id': None, 'name': 'CBS Sports'},
#    'author': None,
#    'title': 'MLB rumors: Latest news from Winter Meetings, live updates as Yankees, others move on after Juan Soto deal - CBS Sports',
#    'description': None,
#    'url': 'https://www.cbssports.com/mlb/news/mlb-rumors-latest-news-from-winter-meetings-live-updates-as-yankees-others-move-on-after-juan-soto-deal/live/',
#    'urlToImage': None,
#    'publishedAt': '2024-12-09T16:16:02Z',
#    'content': None},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': 'BBC.com',
#    'title': 'Premier League LIVE: Weekend reaction, Champions League team news and Phil McNulty Q&A - BBC.com',
#    'description': None,
#    'url': 'https://news.google.com/rss/articles/CBMiYkFVX3lxTFBERk9GeVY5REljNGpxS190dTJCOUFFbmhab2pIQVQ0Y2haLW5qWXAtc3J1VXpHUWZKOHByVk9jbEFNbUoxUDVIOVZ0aWcyVTVCZldYSUV5QVJEN3lpVFNnTy13?oc=5',
#    'urlToImage': None,
# ...

# %%
import requests
import requests as r
import pandas as pd
url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'health',
    'category':  'technology',
    'category':  'sports',
    'apikey': '4dbedf035ac440d8a6f8f666b20b9220'
}
response = r.get(url, params=params)

#save response to a json file
data = response.json()
df = pd.DataFrame(data)
df.to_csv('dataman.csv', index=True)
df = pd.read_csv('dataman.csv', index_col=0)
df
# Out:
#    status  totalResults                                           articles
# 0      ok            29  {'source': {'id': None, 'name': 'NBCSports.com...
# 1      ok            29  {'source': {'id': None, 'name': 'Sports Illust...
# 2      ok            29  {'source': {'id': 'fox-sports', 'name': 'Fox S...
# 3      ok            29  {'source': {'id': None, 'name': 'CBS Sports'},...
# 4      ok            29  {'source': {'id': None, 'name': 'CBS Sports'},...
# 5      ok            29  {'source': {'id': None, 'name': 'NBCSports.com...
# 6      ok            29  {'source': {'id': None, 'name': 'CBS Sports'},...
# 7      ok            29  {'source': {'id': 'bleacher-report', 'name': '...
# 8      ok            29  {'source': {'id': None, 'name': 'Silver And Bl...
# 9      ok            29  {'source': {'id': 'espn', 'name': 'ESPN'}, 'au...
# 10     ok            29  {'source': {'id': None, 'name': 'NCAA.com'}, '...
# ...

# %%
import requests
import requests as r
import pandas as pd
url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'health',
    'category':  'technology',
    'category':  'sports',
    'apikey': '4dbedf035ac440d8a6f8f666b20b9220'
}
response = r.get(url, params=params)

#save response to a json file
news_data = response.json()

if response.status_code == 200:
    for article in news_data.get('articles', []):
       full_article = []
       full_article.append([article.get('title','N/A'), article.get('description', 'N/A')])
       print(full_article)
# Out:
# [['MLB rumors: Latest news from Winter Meetings, live updates as Yankees, others move on after Juan Soto deal - CBS Sports', None]]
# [['Premier League LIVE: Weekend reaction, Champions League team news and Phil McNulty Q&A - BBC.com', None]]
# [['Odd Week 15 schedule has glut of great 4:25 p.m. ET games - NBC Sports', 'The byes are over.']]
# [["NFL Week 14 grades: Rams earn high mark for upset win over Bills, Steelers get 'A-' for beating Browns - CBS Sports", 'Here are the grades for every team that played in Week 14']]
# [["Ranking the top 10 QBs in the transfer portal: Who's the best available? - ESPN", 'The college football transfer portal is open, and several top quarterbacks are looking for new schools. Here are the best available.']]
# [['Panthers want to go from "being close" to being winners - NBC Sports', 'The Panthers have been playing some of their best football of the season over the last three weeks, but their hard work has not resulted in a win.']]
# ...

# %%
import requests
import requests as r
import pandas as pd
url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'technology',
    'apikey': '4dbedf035ac440d8a6f8f666b20b9220'
}
response = r.get(url, params=params)

#save response to a json file
news_data = response.json()

if response.status_code == 200:
    for article in news_data.get('articles', []):
       full_article = []
       full_article.append([article.get('title','N/A'), article.get('description', 'N/A')])
       df = pd.DataFrame(full_article)
       df.to_csv('articles.csv', index=True)
       df = pd.read_csv('articles.csv', index_col=0)
       print(df.T)
# Out:
#                                                    0
# 0  Apple Seeds Second Release Candidate Versions ...
# 1  Apple today seeded the second release candidat...
#                                                    0
# 0  OpenAI's Sora video generator is launching for...
# 1  Judging by a new support page, it seems that u...
#                                                    0
# 0  “AI-driven” anti-phishing complaint briefly ta...
# 1  Domain registrar failed to respond after offen...
#                                                    0
# 0  Google’s Pixel Tablet has returned to its Blac...
# 1  The Google Pixel Tablet starts at $279 at Amaz...
#                                                    0
# 0  Review: Legacy Of Kain: Soul Reaver 1 & 2 Rema...
# 1                                      Soul survivor
#                                                    0
# 0  Cyberpunk 2077 Gets Surprise Update 2.2, CD Pr...
# 1  Cyberpunk 2077 developer CD Projekt was though...
# ...

# %%
import requests
import requests as r
import pandas as pd

url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'technology',
    'apikey': '4dbedf035ac440d8a6f8f666b20b9220'
}
response = r.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    articles = []
    for article in data.get('articles'):
        articles.append({
            'Title' : article.get('title', 'N/A'),
            'Author' : article.get('author', 'N/A'),
            'Url' : article.get('url', 'N/A'),
            'Description': article.get('description', 'N/A')
        })

df = pd.DataFrame(articles)
df
# Out:
#                                                 Title  \
# 0   Apple Seeds Second Release Candidate Versions ...
# 1   OpenAI's Sora video generator is launching for...
# 2   “AI-driven” anti-phishing complaint briefly ta...
# 3   Google’s Pixel Tablet has returned to its Blac...
# 4   Review: Legacy Of Kain: Soul Reaver 1 & 2 Rema...
# 5   Cyberpunk 2077 Gets Surprise Update 2.2, CD Pr...
# 6   Mighty Morphin Power Rangers: Rita’s Rewind Re...
# 7   Introducing a New Text Chat Experience in Fort...
# 8                                           [Removed]
# 9   Path Of Exile 2 Already Has Major Nerfs After ...
# 10  Infinity Nikki has topped 10 million downloads...
# 11                                          [Removed]
# 12  Indie RPG Hit 'Chained Echoes' Announces 'Ashe...
# 13  How To Punch Fascists Even Better In Indiana J...
# 14  Xbox Game Pass Ultimate just got an massive 50...
# 15  Microsoft’s AI boss and Sam Altman disagree on...
# ...

# %%
import requests
import requests as r
import pandas as pd

url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'health',
    'category':  'technology',
    'apikey': '4dbedf035ac440d8a6f8f666b20b9220'
}
response = r.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    articles = []
    for article in data.get('articles'):
        articles.append({
            'Title' : article.get('title', 'N/A'),
            'Author' : article.get('author', 'N/A'),
            'Url' : article.get('url', 'N/A'),
            'Description': article.get('description', 'N/A')
        })

df = pd.DataFrame(articles)
print(df.T)
# Out:
#                                                             0   \
# Title        Apple Seeds Second Release Candidate Versions ...
# Author                                             Juli Clover
# Url          https://www.macrumors.com/2024/12/09/apple-see...
# Description  Apple today seeded the second release candidat...
#
#                                                             1   \
# Title        OpenAI's Sora video generator is launching for...
# Author                                            Kyle Wiggers
# Url          https://techcrunch.com/2024/12/09/openais-sora...
# Description  Judging by a new support page, it seems that u...
#
#                                                             2   \
# Title        “AI-driven” anti-phishing complaint briefly ta...
# Author                                             Kyle Orland
# Url          https://arstechnica.com/gaming/2024/12/itch-io...
# Description  Domain registrar failed to respond after offen...
#
# ...
