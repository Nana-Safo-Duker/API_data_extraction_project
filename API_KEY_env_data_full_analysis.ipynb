# %%
import requests as r
from dotenv import load_dotenv
import os

# Load envirogtent varlables from.env file
load_dotenv('API_KEY.env')

#Access the API key from environent variablesapi_key-os-getenv("APT_KFY)
api_key = os.getenv('API_KEY')

url = 'https://newsapi.org/v2/top-headlines'
params = {"country" : 'us'}
headers = {"Authorization" :f'Bearer {api_key}'}
         
response = r.get(url, params=params, headers=headers)

data = response.json()
print(data)
# Out:
# {'status': 'ok', 'totalResults': 34, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Karla Adam', 'title': 'Trump reports King Charles is ‘fighting very hard’ against cancer - The Washington Post', 'description': 'Trump’s account of a conversation with Prince William is getting attention because the royal family has said little about the king’s health.', 'url': 'https://www.washingtonpost.com/world/2024/12/09/trump-king-charles-fighting-cancer-prince-william/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/VCHPEEM43GDJO2VA5M2SE4SECA.JPG&w=1440', 'publishedAt': '2024-12-09T18:10:36Z', 'content': 'LONDON Britains King Charles III is fighting very hard in his battle with cancer, according to President-elect Donald Trumps account of a conversation he had with Prince William.\r\nThe comment, publis… [+257 chars]'}, {'source': {'id': 'techcrunch', 'nam
# ...

# %%
import requests as r
import pandas as pd
from dotenv import load_dotenv
import os

# Load envirogtent varlables from.env file
load_dotenv('API_KEY.env')

#Access the API key from environent variablesapi_key-os-getenv("APT_KFY)
api_key = os.getenv('API_KEY')

url = 'https://newsapi.org/v2/top-headlines'
params = {"country" : 'us'}
headers = {"Authorization" :f'Bearer {api_key}'}
         
response = r.get(url, params=params, headers=headers)

data = response.json()
df = pd.DataFrame(data)
df.to_csv('dataman.csv', index=True)
df = pd.read_csv('dataman.csv', index_col=0)
df
# Out:
#    status  totalResults                                           articles
# 0      ok            34  {'source': {'id': 'the-washington-post', 'name...
# 1      ok            34  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 2      ok            34  {'source': {'id': None, 'name': 'DW (English)'...
# 3      ok            34  {'source': {'id': 'the-washington-post', 'name...
# 4      ok            34  {'source': {'id': None, 'name': 'MarketWatch'}...
# 5      ok            34  {'source': {'id': None, 'name': '[Removed]'}, ...
# 6      ok            34  {'source': {'id': None, 'name': 'Sports Illust...
# 7      ok            34  {'source': {'id': 'fox-sports', 'name': 'Fox S...
# 8      ok            34  {'source': {'id': 'the-wall-street-journal', '...
# 9      ok            34  {'source': {'id': 'the-washington-post', 'name...
# 10     ok            34  {'source': {'id': None, 'name': 'CNBC'}, 'auth...
# ...

# %%
import requests as r
import pandas as pd
from dotenv import load_dotenv
import os


# Load envirogtent varlables from.env file
load_dotenv('API_KEY.env')

#Access the API key from environent variablesapi_key-os-getenv("APT_KFY)
api_key = os.getenv('API_KEY')

url = 'https://newsapi.org/v2/top-headlines'
params = {"country" : 'us'}
headers = {"Authorization" :f'Bearer {api_key}'}
         
response = r.get(url, params=params, headers=headers)

if response.status_code == 200:
    data = response.json()
    articles = []
    for article in data.get('articles'):
        articles.append({
            'Title' : article.get('title', 'N/A'),
            'Author' : article.get('author', 'N/A'),
            'Url' : article.get('url', 'N/A'),
            'Description': article.get('description', 'N/A')
        })

df = pd.DataFrame(articles)
df
# Out:
#                                                 Title  \
# 0   Trump reports King Charles is ‘fighting very h...
# 1   OpenAI's Sora video generator is launching for...
# 2   Syria updates: Germany halts asylum proceeding...
# 3   Taylor Swift’s final Eras Tour show was classi...
# 4   AppLovin’s S&P 500 snub could make for the sto...
# 5                                           [Removed]
# 6   How an Overzealous Yankees Security Guard Help...
# 7   2024 College Football Playoff odds: Who will e...
# 8   Omnicom to Acquire Interpublic in Deal That Wi...
# 9   TikTok asks court to pause law that could shut...
# 10  Brian Thompson killing: Man questioned in Penn...
# 11  Haiti Gangs Kill More Than 180 Mostly Elderly ...
# 12  When Deadpool Meets Spider-Man: Ryan Reynolds ...
# 13  Assad's fall in Syria weakens Iran but may fue...
# 14  NFL Week 14 grades: Rams earn high mark for up...
# 15  Syrians in UK react to Assad's downfall - BBC.com
# ...

# %%
import requests
import requests as r
import pandas as pd


# Load envirogtent varlables from.env file
load_dotenv('API_KEY.env')

#Access the API key from environent variablesapi_key-os-getenv("APT_KFY)
api_key = os.getenv('API_KEY')

url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'health',
    'category':  'technology',
    'category':  'sports'
}
headers = {"Authorization" :f'Bearer {api_key}'}
         
response = r.get(url, params=params, headers=headers)

#save response to a json file
news_data = response.json()

if response.status_code == 200:
    for article in news_data.get('articles', []):
       full_article = []
       full_article.append([article.get('title','N/A'), article.get('description', 'N/A')])
       print(full_article)
# Out:
# [['Saquon Barkley needs 483 yards in final four games to break NFL single-season record - NBC Sports', "Eric Dickerson's 40-year-old record is in jeopardy."]]
# [['How an Overzealous Yankees Security Guard Helped the Mets Land Juan Soto - Sports Illustrated', 'The Mets used their league intelligence to their advantage.']]
# [['2024 College Football Playoff odds: Who will emerge from the first round? - FOX Sports', 'The College Football Playoff field is set, and it begins with the first round. Check out the odds for all four heavyweight matchups.']]
# [['Ranking all 41 college football bowl games for 2024-25: Orange, Cotton entice as Pop-Tarts leads best of rest - CBS Sports', 'Taking you from the Salute to Veterans Bowl through the College Football Playoff']]
# [['MLB free agency predictions for top 10 players left: Alex Bregman joins Red Sox, Pete Alonso stays in NL East - CBS Sports', 'Juan Soto is heading to the Mets, but there are plenty of big names remaining in free agency']]
# ...

# %%
import requests
import requests as r
import pandas as pd


# Load envirogtent varlables from.env file
load_dotenv('API_KEY.env')

#Access the API key from environent variablesapi_key-os-getenv("APT_KFY)
api_key = os.getenv('API_KEY')

url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us',
    'category':  'technology'
}
headers = {"Authorization" :f'Bearer {api_key}'}
         
response = r.get(url, params=params, headers=headers)

#save response to a json file
news_data = response.json()

if response.status_code == 200:
    for article in news_data.get('articles', []):
       full_article = []
       full_article.append([article.get('title','N/A'), article.get('description', 'N/A')])

df = pd.DataFrame(full_article)
df
# Out:
#                                                    0  \
# 0  Here Are Five Different ‘Marvel Rivals’ Charac...
#
#                                                    1
# 0  Everyone wants to see a Marvel Rivals tier lis...

# %%
import requests
import requests as r
import pandas as pd

# Load envirogtent varlables from.env file
load_dotenv('API_KEY.env')

#Access the API key from environent variablesapi_key-os-getenv("APT_KFY)
api_key = os.getenv('API_KEY')

url = 'https://newsapi.org/v2/top-headlines'
params = {
    'country': 'us'
}
headers = {"Authorization" :f'Bearer {api_key}'}
         
response = r.get(url, params=params, headers=headers)

#save response to a json file
news_data = response.json()

if response.status_code == 200:
    for article in news_data.get('articles', []):
       full_article = []
       full_article.append([article.get('title','N/A'), article.get('description', 'N/A')])
       df = pd.DataFrame(full_article)
       df.to_csv('articles.csv', index=True)
       df = pd.read_csv('articles.csv', index_col=0)
       print(df)
# Out:
#                                                    0  \
# 0  Trump reports King Charles is ‘fighting very h...
#
#                                                    1
# 0  Trump’s account of a conversation with Prince ...
#                                                    0  \
# 0  OpenAI's Sora video generator is launching for...
#
#                                                    1
# 0  Judging by a new support page, it seems that u...
#                                                    0  \
# 0  Syria updates: Germany halts asylum proceeding...
#
#                                                    1
# 0  Germany is reportedly putting a halt on asylum...
#                                                    0  \
# 0  Taylor Swift’s final Eras Tour show was classi...
#
#                                                    1
# 0  Theories swirled about whether Taylor Swift wo...
#                                                    0   1
# ...
